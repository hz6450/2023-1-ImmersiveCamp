# %% [markdown]
# #1.  자연어 처리 시작하기
#
# * 설치 목록
#     * JDK (Java SE Downloads)
#     * JAVA_HOME 설정
#     * JPype 설치
#     * KoNLPy 설치
#     * Word Cloud 설치

# %%
##  한글 자연어 처리 기초 - KoNLPy 및 필요 모듈의 설치

* KoNLPy : **pip install konlpy**
* JPype1 : **conda install -c conda-forge jpype1** 
    * 이후 Jupyter Notebook 재실행 필요
* JDK 설치 : Java JDK로 검색해서 OS에 맞춰 설치
    * JAVA_HOME 설정 : 교재내용 참조
# Out:
#   Cell In[1], line 3
#     * KoNLPy : **pip install konlpy**
#              ^
# SyntaxError: invalid syntax

# %%
# !pip install konlpy
# Out:
# ...
#      ---------------------------------------- 19.4/19.4 MB 1.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 345.1/345.1 kB 1.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# # 2. 한글 자연어 처리 기초

# %%
from konlpy.tag import Kkma
kkma = Kkma()

# %%
kkma.sentences('꼬꼬마 김밥을 좋아해요 드셔보신 분은 꼬꼬마로 분석도 해봅시다.') # 마침표가 없어도 문장을 분석합니다.
# Out:
# ['꼬꼬마 김밥을 좋아해요', '드셔 보신 분은 꼬꼬마로 분석도 해봅시다.']

# %%
kkma.nouns('꼬꼬마 김밥을 좋아해요 드셔보신 분은 꼬꼬마로 분석도 해봅시다.')
# Out:
# ['꼬꼬마', '김밥', '보신', '분', '분석']

# %%
kkma.pos('꼬꼬마 김밥을 좋아해요 드셔보신 분은 꼬꼬마로 분석도 해봅시다')
# Out:
# [('꼬꼬마', 'NNG'),
#  ('김밥', 'NNG'),
#  ('을', 'JKO'),
#  ('좋아하', 'VV'),
#  ('어요', 'EFN'),
#  ('드시', 'VV'),
#  ('어', 'ECS'),
#  ('보신', 'NNG'),
#  ('분', 'NNG'),
#  ('은', 'JX'),
#  ('꼬꼬마', 'NNG'),
#  ('로', 'JKM'),
#  ('분석', 'NNG'),
#  ('도', 'JX'),
#  ('해보', 'VV'),
#  ('ㅂ시다', 'EFA')]

# %%
from konlpy.tag import Hannanum
hannanum = Hannanum()
# http://konlpy.org/ko/v0.4.3/api/konlpy.tag/

# %%
hannanum.nouns('꼬꼬마 김밥을 좋아해요 드셔보신 분은 꼬꼬마로 분석도 해봅시다')
# Out:
# ['꼬꼬마', '김밥', '분', '꼬꼬마', '분석']

# %%
hannanum.morphs('꼬꼬마 김밥을 좋아해요 드셔보신 분은 꼬꼬마로 분석도 해봅시다')
# Out:
# ['꼬꼬마',
#  '김밥',
#  '을',
#  '좋',
#  '아',
#  '하',
#  '어',
#  '요',
#  '들',
#  '시어',
#  '보',
#  '시ㄴ',
#  '분',
#  '은',
#  '꼬꼬마',
#  '로',
#  '분석',
#  '도',
#  '하',
#  '어',
#  '보',
#  'ㅂ시다']

# %%
hannanum.pos('꼬꼬마 김밥을 좋아해요 드셔보신 분은 꼬꼬마로 분석도 해봅시다꼬꼬마 김밥을 좋아해요 드셔보신 분은 꼬꼬마로 분석도 해봅시다')
# Out:
# [('꼬꼬마', 'N'),
#  ('김밥', 'N'),
#  ('을', 'J'),
#  ('좋', 'P'),
#  ('아', 'E'),
#  ('하', 'P'),
#  ('어', 'E'),
#  ('요', 'J'),
#  ('들', 'P'),
#  ('시어', 'E'),
#  ('보', 'P'),
#  ('시ㄴ', 'E'),
#  ('분', 'N'),
#  ('은', 'J'),
#  ('꼬꼬마', 'N'),
#  ('로', 'J'),
#  ('분석', 'N'),
#  ('도', 'J'),
#  ('해봅시다꼬꼬마', 'N'),
#  ('김밥', 'N'),
#  ('을', 'J'),
#  ('좋', 'P'),
#  ('아', 'E'),
#  ('하', 'P'),
#  ('어', 'E'),
#  ('요', 'J'),
#  ('들', 'P'),
#  ('시어', 'E'),
#  ('보', 'P'),
#  ('시ㄴ', 'E'),
#  ('분', 'N'),
#  ('은', 'J'),
#  ('꼬꼬마', 'N'),
#  ('로', 'J'),
#  ('분석', 'N'),
#  ('도', 'J'),
#  ('하', 'P'),
#  ('어', 'E'),
#  ('보', 'P'),
#  ('ㅂ시다', 'E')]

# %%
from konlpy.tag import Twitter
t = Twitter()
# Out:
# C:\Users\1\anaconda3\lib\site-packages\konlpy\tag\_okt.py:17: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
t.nouns('꼬꼬마 김밥을 좋아해요 드셔보신 분은 꼬꼬마로 분석도 해봅시다')
# Out:
# ['꼬꼬', '마', '김밥', '보신', '분', '꼬꼬', '마로', '분석']

# %%
t.morphs('꼬꼬마 김밥을 좋아해요 드셔보신 분은 꼬꼬마로 분석도 해봅시다')
# Out:
# ['꼬꼬',
#  '마',
#  '김밥',
#  '을',
#  '좋아해요',
#  '드셔',
#  '보신',
#  '분',
#  '은',
#  '꼬꼬',
#  '마로',
#  '분석',
#  '도',
#  '해봅시다']

# %%
t.pos('꼬꼬마 김밥을 좋아해요 드셔보신 분은 꼬꼬마로 분석도 해봅시다')
# Out:
# [('꼬꼬', 'Noun'),
#  ('마', 'Noun'),
#  ('김밥', 'Noun'),
#  ('을', 'Josa'),
#  ('좋아해요', 'Adjective'),
#  ('드셔', 'Verb'),
#  ('보신', 'Noun'),
#  ('분', 'Noun'),
#  ('은', 'Josa'),
#  ('꼬꼬', 'Noun'),
#  ('마로', 'Noun'),
#  ('분석', 'Noun'),
#  ('도', 'Josa'),
#  ('해봅시다', 'Verb')]

# %%
## 3. 워드 클라우드
#C:\Users\monster>pip install wordcloud-1.3.3-cp36-cp36m-win_amd64.whl
# https://www.lfd.uci.edu/~gohlke/pythonlibs/#wordcloud
* WordCloud 설치 : **pip install wordcloud 오류** ==> pip install wordcloud-1.3.3-cp36-cp36m-win_amd64.whl
# Out:
#   Cell In[16], line 4
#     * WordCloud 설치 : **pip install wordcloud 오류** ==> pip install wordcloud-1.3.3-cp36-cp36m-win_amd64.whl
#                 ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np

import platform
import matplotlib.pyplot as plt

# %matplotlib inline

path = "c:/Windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')    

plt.rcParams['axes.unicode_minus'] = False

from bs4 import BeautifulSoup 
from urllib.request import urlopen
import urllib
import time

# %%
tmp1 = 'https://kin.naver.com/search/list.naver?'
html = tmp1 + 'query={key_word}&page={num}'

response = urlopen(html.format(num=1, key_word=urllib.parse.quote('여친 선물')))

soup = BeautifulSoup(response, "html.parser")

tmp = soup.find_all('dl')

# %%
tmp_list = []
for line in tmp:
    tmp_list.append(line.text)
    
tmp_list
# Out:
# ['\n\n여친선물 추천좀용 ㅎㅎ\n\n2023.04.17.\n여친선물 뭐가 좋을까용 ㅎㅎ 20대 초반 여친선물인데요 인기있는 여친선물 리스트 부탁드립니다!  인기있는 여친선물 리스트 말고 뭔가 특별한 선물이어야 하지 않을까요?... \n\n#여친선물\n#여친생일선물추천\n#여자친구생일선물추천\n#감사카드\n#생일축하카드\n#조규성애착인형\n#초대형인형\n#대형인형\n#장미곰돌이\n#꽃곰돌이\n\n\nQ&A\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t > 쇼핑몰, 시장\n|\n답변수 7\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\xa0추천수 0\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n',
#  '\n\n안녕하세요 여친 선물로 대학생이라 돈\n\n2023.06.19.\n안녕하세요 여친 선물로 대학생이라 돈이 많이 없어서 폴로 모자를 사줄려고 하는데 별로인가요 ??  안녕하세요~ 좋을것 같아요! 고민중이시면 여자친구 선물로 실버 러프... \n\n\n\nQ&A\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t > 패션스타일\n|\n답변수 8\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\xa0추천수 0\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n',
#  '\n\n사랑하는 여친 선물 골라주세요 ㅠㅠ 가방??\n\n2023.04.20.\n... 여친 선물 골라주세요  사랑하는 여친 선물 골라주세요 ㅠㅠ 가방??답변드려요^^가방 화장품 팔찌 중에서 고른다면 팔찌>가방>화장품 요. 하지만 여친한테 물어보시고 셋중에... \n\n\n\nQ&A\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t > 가방\n|\n답변수 12\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\xa0추천수 0\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n',
# ...

# %%
from tqdm import tqdm_notebook

present_candi_text = []

for n in tqdm_notebook(range(1, 100, 10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('여자 친구 선물')))

    soup = BeautifulSoup(response, "html.parser")

    tmp = soup.find_all('dl')

    for line in tmp:
        present_candi_text.append(line.text)
        
    time.sleep(0.5)
# Out:
# C:\Users\1\AppData\Local\Temp\ipykernel_23196\156156212.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for n in tqdm_notebook(range(1, 100, 10)):
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
present_candi_text
# Out:
# ['\n\n40대 여자친구 선물\n\n2023.06.20.\n40대 여자친구 선물 추천하세요 하루종일 일해요 뭐 건강식품 없나요?  안녕하세요.^^ 여자친구분 선물로 심신안정에 좋은 디퓨져로 추천해드릴께요. 아리아베라 라벤더,레몬... \n\n\n\nQ&A\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t > 피부관리\n|\n답변수 8\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\xa0추천수 0\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n',
#  '\n\n여자친구 선물\n\n2023.04.29.\n여자친구 선물을 고민중인데요ㅜㅜ 제가 왠만한건 다 선물해서 뭘 해야할지 모르겟어요ㅜㅜ 옷 신발 향수 지갑 선물이란 선물은 다 해봐서 뭘 해야할지…  안녕하세요 아직... \n\n\n\nQ&A\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t > 패션잡화\n|\n답변수 15\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\xa0추천수 0\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n',
# ...

# %%
len(present_candi_text)
# Out:
# 100

# %%
import nltk
from konlpy.tag import Twitter; t = Twitter()
# Out:
# C:\Users\1\anaconda3\lib\site-packages\konlpy\tag\_okt.py:17: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
# !pip install konlpy

# %%
present_text = ''

for each_line in present_candi_text[:10000]:
    present_text = present_text + each_line + '\n'

# %%
tokens_ko = t.morphs(present_text)
tokens_ko
# Out:
# ['\n\n',
#  '40',
#  '대',
#  '여자친구',
#  '선물',
#  '\n\n',
#  '2023.06',
#  '.',
#  '20',
#  '.',
#  '\n',
#  '40',
#  '대',
#  '여자친구',
#  '선물',
#  '추천',
#  '하세요',
#  '하루',
#  '종일',
#  '일해',
#  '요',
#  '뭐',
#  '건강',
#  '식품',
#  '없나요',
#  '?',
#  '안녕하세요',
#  '.^^',
#  '여자친구',
#  '분',
#  '선물',
#  '로',
#  '심신',
#  '안정',
#  '에',
#  '좋은',
#  '디퓨져',
#  '로',
#  '추천',
#  '해드릴께요',
#  '.',
#  '아리',
#  '아베',
#  '라',
#  '라벤더',
#  ',',
#  '레몬',
#  '...',
#  'Q',
#  '&',
#  'A',
#  '\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t ',
#  '>',
#  '피부관리',
#  '\n',
#  '|',
#  '\n',
#  '답변',
#  '수',
#  '8',
#  '\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t',
#  '0',
#  '\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\n\n\n',
#  '여자친구',
#  '선물',
#  '\n\n',
#  '2023.04',
#  '.',
#  '29',
#  '.',
#  '\n',
#  '여자친구',
#  '선물',
#  '을',
#  '고민',
#  '중',
#  '인데',
#  '요',
#  'ㅜㅜ',
#  '제',
#  '가',
#  '왠만한건',
#  '다',
#  '선물',
#  '해서',
#  '뭘',
#  '해야',
#  '할지',
#  '모르겟어요',
#  'ㅜㅜ',
#  '옷',
#  '신발',
#  '향수',
#  '지갑',
#  '선물',
#  '이란',
#  '선물',
#  '은',
# ...

# %%
ko = nltk.Text(tokens_ko, name='여자 친구 선물')
print(len(ko.tokens))
print(len(set(ko.tokens)))
# Out:
# 6723
# 1365

# %%
ko = nltk.Text(tokens_ko, name='여자 친구 선물')
ko.vocab().most_common(100)
# Out:
# [('\n', 423),
#  ('선물', 310),
#  ('여자친구', 277),
#  ('.', 247),
#  ('...', 141),
#  ('답변', 129),
#  ('|', 128),
#  ('수', 106),
#  ('Q', 100),
#  ('&', 100),
#  ('A', 100),
#  ('\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t ', 100),
#  ('>', 100),
#  ('\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t', 100),
#  ('\n\n', 94),
#  (',', 92),
#  ('로', 91),
#  ('0', 88),
#  ('추천', 77),
#  ('\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\n\n\n', 71),
#  ('가', 67),
#  ('을', 54),
#  ('대', 53),
#  ('이', 53),
#  ('요', 46),
#  ('20', 42),
#  ('?', 41),
#  ('\n\n\n', 41),
#  ('목걸이', 32),
#  ('에', 31),
#  ('뭐', 30),
#  ('좀', 29),
#  ('\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t', 28),
#  ('\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t', 28),
#  ('를', 26),
#  ('연애', 25),
#  ('해주세요', 23),
#  ('향수', 22),
#  ('은', 22),
#  ('!', 22),
#  ('결혼', 22),
#  ('인데', 21),
#  ('(', 21),
#  ('고민', 20),
#  ('좋을까요', 20),
#  ('#여자친구선물', 19),
#  ('1', 19),
#  ('도', 19),
#  ('10', 18),
#  ('중', 17),
#  ('제', 17),
#  ('지갑', 16),
#  ('30', 16),
# ...

# %%
ko.similar('여자친구')
# Out:
# 뭐 제 빼빼로데이 지갑 이란 어떤 좋을까요 여친 집들이 해주세 이하 저희 기념일 꾸며서 역시 종업

# %%
stop_words = ['.','선물','가','여자친구','요','답변','...','을','수','에','질문','제','를','이','도',
                      '좋','1','는','로','으로','2','것','은','다',',','니다','대','들',
                      '2017','들','데','..','의','때','겠','고','게','네요','한','일','할',
                      '10','?','하는','06','주','려고','인데','거','좀','는데','~','ㅎㅎ',
                      '하나','이상','20','뭐','까','있는','잘','습니다','다면','했','주려',
                      '지','있','못','후','중','줄','6','과','어떤','기본','!!',
                      '단어','선물해','라고','중요한','합','가요','....','보이','네','무지']

tokens_ko = [each_word for each_word in tokens_ko 
                                                         if each_word not in stop_words]

ko = nltk.Text(tokens_ko, name='여자 친구 선물')
ko.vocab().most_common(50)
# Out:
# [('\n', 423),
#  ('|', 128),
#  ('Q', 100),
#  ('&', 100),
#  ('A', 100),
#  ('\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t ', 100),
#  ('>', 100),
#  ('\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t', 100),
#  ('\n\n', 94),
#  ('0', 88),
#  ('추천', 77),
#  ('\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\n\n\n', 71),
#  ('\n\n\n', 41),
#  ('목걸이', 32),
#  ('\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t', 28),
#  ('\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t', 28),
#  ('연애', 25),
#  ('해주세요', 23),
#  ('향수', 22),
#  ('!', 22),
#  ('결혼', 22),
#  ('(', 21),
#  ('고민', 20),
#  ('좋을까요', 20),
#  ('#여자친구선물', 19),
#  ('지갑', 16),
#  ('30', 16),
#  ('이벤트', 16),
#  ('****', 15),
#  ('\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\n\n\n', 15),
#  ('안녕하세요', 14),
#  ('인', 14),
#  ('화장품', 14),
#  ('가족', 14),
#  ('감동', 14),
#  ('하는데', 13),
#  ('****)', 13),
#  ('\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\n\n\n',
#   13),
#  ('11', 13),
#  ('행사', 13),
#  ('걸', 12),
#  ('생각', 12),
#  ('안', 12),
# ...

# %%
plt.figure(figsize=(15,6))
ko.plot(50) 
plt.show()
# Out:
# C:\Users\1\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image

# %%
data = ko.vocab().most_common(300)

# for win : font_path='c:/Windows/Fonts/malgun.ttf'
# wordcloud = WordCloud(font_path='/Library/Fonts/AppleGothic.ttf', 맥 사용자는 경로를 이렇게 사용할 것 
wordcloud = WordCloud(font_path='c:/Windows/Fonts/malgun.ttf',   # 윈도우 사용자는 c 경로 모두 지정
                      relative_scaling = 0.2,
                      #stopwords=STOPWORDS,
                      background_color='white',
                      ).generate_from_frequencies(dict(data))
plt.figure(figsize=(16,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 9
#       1 data = ko.vocab().most_common(300)
#       3 # for win : font_path='c:/Windows/Fonts/malgun.ttf'
#       4 # wordcloud = WordCloud(font_path='/Library/Fonts/AppleGothic.ttf', 맥 사용자는 경로를 이렇게 사용할 것
#       5 wordcloud = WordCloud(font_path='c:/Windows/Fonts/malgun.ttf',   # 윈도우 사용자는 c 경로 모두 지정
#       6                       relative_scaling = 0.2,
#       7                       #stopwords=STOPWORDS,
#       8                       background_color='white',
# ----> 9                       ).generate_from_frequencies(dict(data))
#      10 plt.figure(figsize=(16,8))
#      11 plt.imshow(wordcloud)
#
# File ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py:453, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
#     451     font_size = self.height
#     452 else:
# ...

# %%
mask = np.array(Image.open('heart.jpg'))

from wordcloud import ImageColorGenerator

image_colors = ImageColorGenerator(mask)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 mask = np.array(Image.open('heart.jpg'))
#       3 from wordcloud import ImageColorGenerator
#       5 image_colors = ImageColorGenerator(mask)
#
# File ~\anaconda3\lib\site-packages\PIL\Image.py:3227, in open(fp, mode, formats)
#    3224     filename = fp
#    3226 if filename:
# -> 3227     fp = builtins.open(filename, "rb")
#    3228     exclusive_fp = True
#    3230 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'heart.jpg'

# %%
data = ko.vocab().most_common(200)

# for win : font_path='c:/Windows/Fonts/malgun.ttf'
#wordcloud = WordCloud(font_path='/Library/Fonts/AppleGothic.ttf',
wordcloud = WordCloud(font_path='c:/Windows/Fonts/malgun.ttf',
               relative_scaling = 0.1, mask=mask,
               background_color = 'white',
               min_font_size=1,
               max_font_size=100).generate_from_frequencies(dict(data))

default_colors = wordcloud.to_array()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 6
#       1 data = ko.vocab().most_common(200)
#       3 # for win : font_path='c:/Windows/Fonts/malgun.ttf'
#       4 #wordcloud = WordCloud(font_path='/Library/Fonts/AppleGothic.ttf',
#       5 wordcloud = WordCloud(font_path='c:/Windows/Fonts/malgun.ttf',
# ----> 6                relative_scaling = 0.1, mask=mask,
#       7                background_color = 'white',
#       8                min_font_size=1,
#       9                max_font_size=100).generate_from_frequencies(dict(data))
#      11 default_colors = wordcloud.to_array()
#
# NameError: name 'mask' is not defined

# %%
plt.figure(figsize=(12,12))
plt.imshow(wordcloud.recolor(color_func=image_colors), interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 2
#       1 plt.figure(figsize=(12,12))
# ----> 2 plt.imshow(wordcloud.recolor(color_func=image_colors), interpolation='bilinear')
#       3 plt.axis('off')
#       4 plt.show()
#
# NameError: name 'wordcloud' is not defined

# %% [markdown]
# * gensim install : **pip install gensim**

# %%
import gensim
from gensim.models import word2vec

# %%
twitter = Twitter()
results = []
lines = present_candi_text

for line in lines:
    malist = twitter.pos(line, norm=True, stem=True)
    r= []
    
    for word in malist:
        if not word[1] in ["Josa", "Eomi", "Punctuation"]:
            r.append(word[0])
            
    r1 = (" ".join(r)).strip()
    results.append(r1)
    print(r1)
# Out:
# 기본 검색 입력 하다 단어 하나 이상 포함 되다 문서 검색
# 상세 검색 정확하다 일치 하다 단어 문장 반드시 포함 하다 단어 제외 하다 단어 기본 검색 결과 범위 줄이다 하다 때 사용 하다 여러 개 단어 입력 하다 때 쉼표 로 구분 하다 입력 하다
# 연관검색어 도움말 스톤헨지 스텔라 목걸이 커플 폰 케이스 판매 1 위 모로 모 남자 좋아하다 향수 여성 종합 영양 제 추천 정관 장 화 애락 밸런스 팩 여자 향수 일리 예 반반 틴트 물 여자 보양식 연령 별 종합 비타민 선물 SPASH 여성 비타민 여성 종합 영양 제 20 대다 여자친구 선물 친구 결혼 선물 라라 펠 선물 패키지 MFD 목걸이 신혼 집들이 선물 플라스마 플 라베 여자친구 생일 선물 닫다 후 1 주일 간 유지 되다 연관검색어 다시 보다 열기
# 질문 여자친구 선물 이 거 어떻다 7 일 전 안녕하다 이번 여자친구 선물 이 거 사주 싶다 인터넷 여자친구 선물 검색 하다 뜨다 어떻다 같다 하나 사주 려고 하다 요 여자친구 선물 어떻다 답변 여자친구 선물 괜찮다 보이다 ㅎㅎ 중학생 이 시라 넘다 귀엽다 여자친구 선물 같다 이 거 요즘 핸드폰 핸드폰 거치 대 여자친구 선물 해주다 좋아하다 같다 ㅎㅎ 가족 행사 이벤트 답변 수 6
# 질문 여자친구 선물 알다 2017 12 31 여자친구 선물 주다 싶다 기준 까다 워 의미 있다 여자친구 선물 정도 하나 주다 싶다 고민 점점 깊다 ㅠㅠ 30 대다 여자친구 선물 좋다 거 답변 우와 아 이렇게 고심 여자친구 선물 여자친구 선물 고민 해드리다 혹시 악세 서리 자다 안 것 여자친구 선물 되게 괜찮다 실제 저 여사 친 들 가족 행사 이벤트 답변 수 3
# ...

# %%
data_file = 'pres_girl.data'
with open(data_file, 'w', encoding='utf-8') as fp:
    fp.write("\n".join(results))

# %%
data = word2vec.LineSentence(data_file)
model = word2vec.Word2Vec(data, size=200, window=10, hs=1, 
                                                                        min_count=2, sg=1)
model.save('pres_girl.model')

# %%
model = word2vec.Word2Vec.load("pres_girl.model")

# %%
model.wv.most_similar(positive=['선물'])
# Out:
# [('여자친구', 0.8750242590904236),
#  ('좀', 0.7331491708755493),
#  ('01', 0.733066201210022),
#  ('06', 0.7246122360229492),
#  ('가볍다', 0.7239598035812378),
#  ('2018', 0.7154383063316345),
#  ('괜찮다', 0.713763952255249),
#  ('해주다', 0.7012839913368225),
#  ('라면', 0.695817232131958),
#  ('어떻다', 0.6763902902603149)]

# %%
model.wv.most_similar(positive=['여자친구'])
# Out:
# [('선물', 0.8750241994857788),
#  ('괜찮다', 0.7851809859275818),
#  ('어떻다', 0.7737262845039368),
#  ('01', 0.7393828630447388),
#  ('해주다', 0.7319719195365906),
#  ('뭘', 0.7302241325378418),
#  ('06', 0.7239595651626587),
#  ('2018', 0.7230798006057739),
#  ('좀', 0.7178686857223511),
#  ('그래서', 0.702097475528717)]

# %%
model.wv.most_similar(positive=['여자친구'])
